# %%
import pandas as pd
import csv

# %%
file = "data.csv"

# %%
data = pd.read_csv(file, encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  xQY8N_XvtGbearJ5X4QryQ  OwjRMXRC0KyPrIlcjaXeFQ  -MhfebM0QIsKt87iDN-FNw
# 1  UmFMZ8PyXZTY2QcwzsfQYA  nIJD_7ZXHq-FX8byPMOkMQ  lbrU8StCq3yDfr-QMnGrmQ
# 2  LG2ZaYiOgpr2DK_90pYjNw  V34qejxNsCbcgD8C0HVk-Q  HQl28KMwrEKHqhFrrDqVNQ
# 3  i6g_oA9Yf9Y31qt0wibXpw  ofKDkJKXSKZXu5xJNGiiBQ  5JxlZaqCnk1MnbgRirs40Q
# 4  6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg  IS4cv902ykd8wj1TR0N3-A
#
#    stars  useful  funny  cool  \
# 0    2.0       5      0     0
# 1    1.0       1      1     0
# 2    5.0       1      0     0
# 3    1.0       0      0     0
# 4    4.0       0      0     0
#
#                                                 text                 date
# 0  As someone who has worked with many museums, I...  2015-04-15 05:21:16
# 1  I am actually horrified this place is still in...  2013-12-07 03:16:52
# 2  I love Deagan's. I do. I really do. The atmosp...  2015-12-05 03:18:11
# ...

# %%
data['stars'].value_counts()
# Out:
# 5.0    2606049
# 4.0    1214962
# 1.0     927393
# 3.0     611189
# 2.0     460199
# Name: stars, dtype: int64

# %%
two_star = data[data['stars'] < 3]

# %%
negative = two_star.head(50000)

# %%
negative
# Out:
#                      review_id                 user_id  \
# 0       xQY8N_XvtGbearJ5X4QryQ  OwjRMXRC0KyPrIlcjaXeFQ
# 1       UmFMZ8PyXZTY2QcwzsfQYA  nIJD_7ZXHq-FX8byPMOkMQ
# 3       i6g_oA9Yf9Y31qt0wibXpw  ofKDkJKXSKZXu5xJNGiiBQ
# 15      mjbs5CL4eMu4o6_VtYhN3Q  TF4C-F5iqavACQgKTrbjRA
# 16      bVTjZgRNq8ToxzvtiVrqMA  2hRe26HSCAWbFRn5WChK-Q
# ...                        ...                     ...
# 227361  2H1AS7RhJjn3pN1tlGvroA  nwh1RZfwGlsIIkA5yowT_A
# 227363  oNbR7rvyxHMWm-r6uye5zg  U91KMbPf_jt43sC10ksHiQ
# 227365  sWnNZFQrgNgeenbe3D11NQ  HJj82f-csBI7jjgenwqhvw
# 227378  XDgWjEDLAtSTSsMGWaZhkA  OOi_k-lMHsVwmkosRHvXQA
# 227382  NwjP_bF-ifM8RdnCKCju1A  i9ny3oipXJMfZezK983RAw
#
#                    business_id  stars  useful  funny  cool  \
# 0       -MhfebM0QIsKt87iDN-FNw    2.0       5      0     0
# 1       lbrU8StCq3yDfr-QMnGrmQ    1.0       1      1     0
# 3       5JxlZaqCnk1MnbgRirs40Q    1.0       0      0     0
# 15      7Ka9Pd8X9SRHs1D5EcleLg    1.0       0      0     0
# ...

# %%
four_star = data[data['stars'] > 3]

# %%
four_star
# Out:
#                       review_id                 user_id  \
# 2        LG2ZaYiOgpr2DK_90pYjNw  V34qejxNsCbcgD8C0HVk-Q
# 4        6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg
# 5        L2O_INwlrRuoX05KSjc4eg  5vD2kmE25YBrbayKhykNxQ
# 6        ZayJ1zWyWgY9S_TRLT_y9Q  aq_ZxGHiri48TUXJlpRkCQ
# 7        lpFIJYpsvDxyph-kPzZ6aA  dsd-KNYKMpx6ma_sRWCSkQ
# ...                         ...                     ...
# 5819785  i7mJgyktf6crv4M5SAhHxg  e37Xn0vCdWlkDSBUUTMe0Q
# 5819786  Rn2fC_KK7cWIboIhkuulqg  VNaIK2cr4u7SVy_0AIMvTA
# 5819787  GUX74_ol--8sI05dvsDhSg  jSmWdDUhogMqddvgFSgp7A
# 5819790  WBsyIgd6sF4SegTNDpNhqQ  G9NyxQBvGDK5qxQ5wZChgg
# 5819791  87rY3GVZJxtnwZBngZE29w  PxrhixfSRoIG0-d3g_pmdw
#
#                     business_id  stars  useful  funny  cool  \
# 2        HQl28KMwrEKHqhFrrDqVNQ    5.0       1      0     0
# 4        IS4cv902ykd8wj1TR0N3-A    4.0       0      0     0
# 5        nlxHRv1zXGT0c0K51q3jDg    5.0       2      0     0
# ...

# %%
positive = four_star.head(50000)

# %%
positive
# Out:
#                     review_id                 user_id             business_id  \
# 2      LG2ZaYiOgpr2DK_90pYjNw  V34qejxNsCbcgD8C0HVk-Q  HQl28KMwrEKHqhFrrDqVNQ
# 4      6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg  IS4cv902ykd8wj1TR0N3-A
# 5      L2O_INwlrRuoX05KSjc4eg  5vD2kmE25YBrbayKhykNxQ  nlxHRv1zXGT0c0K51q3jDg
# 6      ZayJ1zWyWgY9S_TRLT_y9Q  aq_ZxGHiri48TUXJlpRkCQ  Pthe4qk5xh4n-ef-9bvMSg
# 7      lpFIJYpsvDxyph-kPzZ6aA  dsd-KNYKMpx6ma_sRWCSkQ  FNCJpSn0tL9iqoY3JC73qw
# ...                       ...                     ...                     ...
# 74652  H5KxXarHMDv-KThyZfn6BA  wNI49PpVAAsvYZM8JZkDrg  55RO-CgxxV7VP1-bXYgJBg
# 74654  bWvapWCGP_YiKJLN6l7fEQ  ZgBSvyTE7WKOb7KZX6iHhA  -X41ylmWxKF4WhkElq0Akg
# 74655  BbPP7d_jfsanfUvEx9X2AA  MzNJ_gbrAbmPrkb6rF4o8A  nMKs_LMNzAzkEB1FwthtOA
# 74656  1XsPAZlRYHVVuj6_xsICNw  CaTOTIBTZpGUClRSN4572Q  -A6iU1EJdtDr-APcJlP3yg
# 74657  l9lxq-XEfyXWlbeQrH7gUg  SA-eKFv0mSzUZgICfD8vrQ  CY36lbBvN5R-1ep46k0RQw
#
# ...

# %%
three_star = data[data['stars'] == 3]

# %%
neutral = three_star.head(500)

# %%
test = pd.concat([negative, positive], ignore_index=True)

# %%
test.to_csv('final_data.csv')
